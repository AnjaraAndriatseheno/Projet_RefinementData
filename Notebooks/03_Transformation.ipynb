# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/processed/dataset_clean_step1.csv")

# %% [markdown]
# Importation de notre dataset nettoyé

# %%
df["Transaction Date"] = pd.to_datetime(
    df["Transaction Date"],
    errors="coerce"
)

# %% [markdown]
# Transformation de la colonne de date

# %%
df["Year"] = df["Transaction Date"].dt.year
df["Month"] = df["Transaction Date"].dt.month
df["Day"] = df["Transaction Date"].dt.day

# %% [markdown]
#  Création de variables temporelles (année, mois, jour) à partir de la date  de transaction afin de faciliter les analyses temporelles

# %%
df["Calculated Total"] = df["Quantity"] * df["Price Per Unit"]

# %% [markdown]
#  Calcul du montant total théorique afin de vérifier la cohérence entre la quantité, le prix unitaire et le montant total enregistré.

# %%
df = pd.get_dummies(
    df,
    columns=["Item", "Payment Method", "Location"],
    drop_first=True
)

# %% [markdown]
# Encodage des variables catégorielles en variables numériques afin de permettre leur utilisation dans des analyses statistiques ou des modèles prédictifs.

# %%
df.drop(columns=["Calculated Total"], inplace=True)

# %% [markdown]
# Suppression des colonnes intermédiaires utilisées uniquement pour la vérificationn de cohérence des données.

# %%
df.to_csv("../data/processed/dataset_clean.csv", index=False)

# %% [markdown]
# Sauvegarde du dataset final après transformation, prêt à être utilisé pour l'analyse ou la modélisation.
