# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/raw/dataset.csv")
df.head()
# Out:
#   Transaction ID    Item Quantity Price Per Unit Total Spent  Payment Method  \
# 0    TXN_1961373  Coffee        2            2.0         4.0     Credit Card
# 1    TXN_4977031    Cake        4            3.0        12.0            Cash
# 2    TXN_4271903  Cookie        4            1.0       ERROR     Credit Card
# 3    TXN_7034554   Salad        2            5.0        10.0         UNKNOWN
# 4    TXN_3160411  Coffee        2            2.0         4.0  Digital Wallet
#
#    Location Transaction Date
# 0  Takeaway       2023-09-08
# 1  In-store       2023-05-16
# 2  In-store       2023-07-19
# 3   UNKNOWN       2023-04-27
# 4  In-store       2023-06-11

# %% [markdown]
# Observation des premières lignes du dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    10000 non-null  object
#  1   Item              9667 non-null   object
#  2   Quantity          9862 non-null   object
#  3   Price Per Unit    9821 non-null   object
#  4   Total Spent       9827 non-null   object
#  5   Payment Method    7421 non-null   object
#  6   Location          6735 non-null   object
#  7   Transaction Date  9841 non-null   object
# dtypes: object(8)
# memory usage: 625.1+ KB

# %% [markdown]
# En lançant une analyse du dataset, on peut observer quelques incohérences :
# - Toutes les colonnes sont en Dtype "object"
# - Les colonnes numériques et temporelles ne sont pas bien typés
#
# Ici on voit bien que les types de données ne sont pas adpatés pour une bonne analyse.

# %%
df.isnull().sum()
# Out:
# Transaction ID         0
# Item                 333
# Quantity             138
# Price Per Unit       179
# Total Spent          173
# Payment Method      2579
# Location            3265
# Transaction Date     159
# dtype: int64

# %% [markdown]
# On peut observer que les plusieurs variables présentent un taux de valeurs manquantes assez importants.

# %%
df["Total Spent"].unique()
df["Payment Method"].unique()
df["Location"].unique()
# Out:
# array(['Takeaway', 'In-store', 'UNKNOWN', nan, 'ERROR'], dtype=object)

# %% [markdown]
# Par exemple ici on constate que des valeurs non exploitables on été intégrées, créeant des valeurs manquantes
